# %% [markdown]
# En este archivo puedes escribir lo que estimes conveniente. Te recomendamos detallar tu solución y todas las suposiciones que estás considerando. Aquí puedes ejecutar las funciones que definiste en los otros archivos de la carpeta src, medir el tiempo, memoria, etc.

# %% [markdown]
# # Solución Challenge

# %% [markdown]
# ## Consideraciones

# %% [markdown]
# Utilicé python 3.8.18 para el desarrollo y testeo de las funciones. La utilicé ya que suelo desarrollar en esta versión.
#
# Las librerías que se deben instalar de manera externa están en el archivo requirements.txt en el ambiente principal del repositorio

# %% [markdown]
# ## Preparación para el testeo

# %% [markdown]
# Primero defino el path del archivo, previamente descargado y descomprimido

# %%
file_path = "farmers-protest-tweets-2021-2-4.json"

# %% [markdown]
# Luego importo las funciones desarrolladas y la librería cProfile que viene por defecto

# %%
import cProfile
from q1_memory import q1_memory
from q1_time import q1_time
from q2_memory import q2_memory
from q2_time import q2_time
from q3_memory import q3_memory
from q3_time import q3_time

# %% [markdown]
# Y por último en la prepación, habilito la utilización de %memit en el notebook con el siguiente comando

# %%
# %load_ext memory_profiler

# %% [markdown]
# ## Soluciones

# %% [markdown]
# Antes de revisar los perfiles de tiempo y memoria, primero presentaré las soluciones, o sea, los output de las funciones, y que ambos approach concuerda

# %%
q1_time(file_path)
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %%
q1_memory(file_path)
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %%
q2_time(file_path)
# Out:
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %%
q2_memory(file_path)
# Out:
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %%
q3_time(file_path)
# Out:
# [('narendramodi', 2135),
#  ('Kisanektamorcha', 1643),
#  ('RakeshTikaitBKU', 1392),
#  ('PMOIndia', 1316),
#  ('RahulGandhi', 1046),
#  ('RaviSinghKA', 969),
#  ('GretaThunberg', 949),
#  ('UNHumanRights', 891),
#  ('rihanna', 875),
#  ('meenaharris', 853)]

# %%
q3_memory(file_path)
# Out:
# [('narendramodi', 2135),
#  ('Kisanektamorcha', 1643),
#  ('RakeshTikaitBKU', 1392),
#  ('PMOIndia', 1316),
#  ('RahulGandhi', 1046),
#  ('RaviSinghKA', 969),
#  ('GretaThunberg', 949),
#  ('UNHumanRights', 891),
#  ('rihanna', 875),
#  ('meenaharris', 853)]

# %% [markdown]
# ## Perfil de Tiempo

# %% [markdown]
# A modo general, utilicé en lo posible métodos de pandas para realizar las operaciones de la manera más rápida posible

# %% [markdown]
# Corro el comando cProfile para las 6 funciones desarrolladas, con la finalidad de comparar el tiempo de ejecución entre la versión que minimiza el tiempo contra la que minimiza el uso de memoria

# %% [markdown]
# ### Problema 1

# %% [markdown]
# En este caso, pese a intentar con diferentes approaches, la solución que desarrollé para minimizar la memoria ulizada, fue también la mejor optimizando para el tiempo [en la última sección Otras Formas Subóptimas], así que dejé la misma implementación para ambas, y la distribución de tiempos de ejecución son idénticas. Mi teoría de porqué fue así es debido a la lectura del archivo, dada su estructura específica [cada elemento corresponde a una fila] pude genarar un código muy eficiente de lectura que a medida que iba leyendo procesaba la información y por eso sucedió eso. Si bien presenté diferentes formas para solucionar el problema, una fue la mejor en ambos aspectos.

# %%
cProfile.run(f"q1_time('{file_path}')")
# Out:
#          1002957 function calls in 10.364 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002   10.364   10.364 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         2    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#     99544    0.076    0.000    0.190    0.000 codecs.py:319(decode)
#         1    0.000    0.000    0.000    0.000 heapq.py:521(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:563(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:577(<listcomp>)
#        13    0.000    0.000    0.000    0.000 q1_time.py:16(<lambda>)
#         1    0.000    0.000    0.000    0.000 q1_time.py:17(<dictcomp>)
#         1    2.644    2.644   10.362   10.362 q1_time.py:9(q1_time)
# ...

# %%
cProfile.run(f"q1_memory('{file_path}')")
# Out:
#          1002957 function calls in 10.530 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002   10.530   10.530 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         2    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#     99544    0.081    0.000    0.196    0.000 codecs.py:319(decode)
#         1    0.000    0.000    0.000    0.000 heapq.py:521(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:563(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:577(<listcomp>)
#        13    0.000    0.000    0.000    0.000 q1_memory.py:16(<lambda>)
#         1    0.000    0.000    0.000    0.000 q1_memory.py:17(<dictcomp>)
#         1    2.709    2.709   10.528   10.528 q1_memory.py:9(q1_memory)
# ...

# %% [markdown]
# ### Problema 2

# %% [markdown]
# En este problema, la diferencia en la performance del tiempo es de unos segundos solamente, y algo curioso es que el approach que minimiza el tiempo hace más llamadas a funciones que la otra.

# %%
cProfile.run(f"q2_time('{file_path}')")
# Out:
#          86081720 function calls in 41.518 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   41.518   41.518 <string>:1(<module>)
#  17023302    4.457    0.000    7.801    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#     49772    0.075    0.000    0.155    0.000 codecs.py:319(decode)
#    117407    0.134    0.000   36.489    0.000 core.py:283(emoji_list)
#    117407    6.392    0.000   36.355    0.000 core.py:290(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:521(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:563(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:577(<listcomp>)
# ...

# %%
cProfile.run(f"q2_memory('{file_path}')")
# Out:
#          85767977 function calls (85767883 primitive calls) in 44.210 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#         9    0.000    0.000    0.033    0.004 <__array_function__ internals>:177(concatenate)
#        65    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(delete)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
# ...

# %% [markdown]
# ### Problema 3

# %% [markdown]
# En este caso la diferencia es muy significativa, casi la mitad del tiempo, o sea, si el data set fuera muchísimo más grande y demorara 2 horas el segundo algoritmo, el primero lo haría solo en 1.

# %%
cProfile.run(f"q3_time('{file_path}')")
# Out:
#          702337 function calls in 4.302 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    4.302    4.302 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#     49772    0.041    0.000    0.099    0.000 codecs.py:319(decode)
#         1    0.005    0.005    0.007    0.007 heapq.py:521(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:563(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:577(<listcomp>)
#     15721    0.001    0.000    0.001    0.000 q3_time.py:17(<lambda>)
#         1    1.225    1.225    4.301    4.301 q3_time.py:9(q3_time)
#    117407    0.066    0.000    0.275    0.000 re.py:233(findall)
# ...

# %%
cProfile.run(f"q3_memory('{file_path}')")
# Out:
#          1357221 function calls (1357117 primitive calls) in 8.925 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#         9    0.000    0.000    0.033    0.004 <__array_function__ internals>:177(concatenate)
#        70    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(delete)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
# ...

# %% [markdown]
# ## Perfil de Memoria

# %% [markdown]
# A grandes rasgos, el approach que tomé para las funciones que minimizan memoria fue la utilización de generadores eb donde sea posible, evitando listas por compresión que alocan memoria antes de si quiera empezar a itera. Inlcuso la lectura del archivo la realicé mediante un generador.
# Con tal de no ocupar mucha memoria, en uno de los casos preferí volver a leer el archivo una segunda vez, ya que si no, hubiese tenido que almacenar mucha información en la primera lectura, pero teniendo ya lo que debía buscar, reduje la cantidad de estructuras de datos y por ende la memoria utilizada.

# %% [markdown]
# ### Problema 1

# %% [markdown]
# Como mencioné en el segmente de tiempo, esta es la misma implementación y posee la misma distribución de uso de memoria, y por ende tendrá valores similares.

# %%
# %memit q1_time(file_path)
# Out:
# peak memory: 204.18 MiB, increment: -1.17 MiB

# %%
# %memit q1_memory(file_path)
# Out:
# peak memory: 200.46 MiB, increment: 0.00 MiB

# %% [markdown]
# Para los siguientes dos casos, pasó lo mismo que en el primero, o sea, la implementación de tiempo no es solo más rápida, si no que también usa menos memoria. La hipotesis que tengo es la misma que la teoría que mencioné en la parte del perfil de tiempo.

# %% [markdown]
# ### Problema 2

# %%
# %memit q2_time(file_path)
# Out:
# peak memory: 199.41 MiB, increment: 0.00 MiB

# %%
# %memit q2_memory(file_path)
# Out:
# peak memory: 1682.41 MiB, increment: 1483.71 MiB

# %% [markdown]
# ### Problema 3

# %%
# %memit q3_time(file_path)
# Out:
# peak memory: 213.16 MiB, increment: 0.00 MiB

# %%
# %memit q3_memory(file_path)
# Out:
# peak memory: 1624.70 MiB, increment: 1425.85 MiB

# %% [markdown]
# ## Otras Formas Subóptimas

# %%
import os
import re
import pandas as pd
import datetime
from collections import defaultdict
import emoji
import ujson
import heapq

# %% [markdown]
# Esta solución se demora casi lo mismo, pero usa 10 veces más memoria

# %%
def q1_context_manager(file_path):
    with open(file_path, "r") as file:
        data = pd.read_json(file, lines=True)
    matches = data["content"].str.extractall(r"@(\S+?) ")
    sol = [(row[0], row['count']) for row in matches[0].value_counts().nlargest(10).reset_index().to_dict('records')]
    return sol

# %%
cProfile.run(f"q1_context_manager('{file_path}')")
# Out:
#          1272515 function calls (1272191 primitive calls) in 10.441 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.021    0.021   10.437   10.437 1669633518.py:1(q1_context_manager)
#         1    0.000    0.000    0.000    0.000 1669633518.py:5(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#        17    0.000    0.000    0.079    0.005 <__array_function__ internals>:177(concatenate)
#        72    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(delete)
# ...

# %%
# %memit q1_context_manager(file_path)
# Out:
# peak memory: 2730.10 MiB, increment: 2241.25 MiB

# %% [markdown]
# La siguiente es incluso más lenta y más exigente en memoria

# %%
def q1_raw_read(file_path):
    data = pd.read_json(file_path, lines=True)
    matches = data["content"].str.extractall(r"@(\S+?) ")
    sol = [(row[0], row['count']) for row in matches[0].value_counts().nlargest(10).reset_index().to_dict('records')]
    return sol

# %%
cProfile.run(f"q1_raw_read('{file_path}')")
# Out:
#          1272661 function calls (1272309 primitive calls) in 12.169 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.037    0.037   12.165   12.165 3872473804.py:1(q1_raw_read)
#         1    0.000    0.000    0.000    0.000 3872473804.py:4(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#        17    0.000    0.000    0.080    0.005 <__array_function__ internals>:177(concatenate)
#        72    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(delete)
# ...

# %%
# %memit q1_raw_read(file_path)
# Out:
# peak memory: 3197.26 MiB, increment: 2310.98 MiB

# %% [markdown]
# Para la siguiente se requiere instalar dask, pero aunque dask es útil para data sets grandes, con este es ineficiente, no es lo suficientemente grande

# %%
def q1_dask(file_path):
    ddf = dd.read_json(file_path, lines=True)
    data = ddf.compute()
    matches = data["content"].str.extractall(r"@(\S+?) ")
    sol = [(row[0], row['count']) for row in matches[0].value_counts().nlargest(10).reset_index().to_dict('records')]
    return sol

# %%
#cProfile.run(f"q1_dask('{file_path}')")

# %%
#%memit q1_dask(file_path)
